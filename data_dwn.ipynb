# %%
import os
import yfinance as yf
import pandas as pd
import pywt
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
df=pd.read_excel("names.xlsx")

# %%
df.dropna(inplace=True)

# %%
names=df['Symbol'].to_list()

# %%
for count in range(len(names)):
    names[count] = names[count] + ".NS"

# %%
nifty_tickers = yf.Tickers(names).tickers

# %%
top_nifty_tickers = [nifty_tickers[t].ticker for t in nifty_tickers]

# %%
daily_data = yf.download(top_nifty_tickers[0], period="max", interval="1d")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
daily_data
# Out:
#                    Open         High          Low        Close    Adj Close
# Date
# 1996-01-01    15.859429    15.944529    15.754989    15.917452     2.369613  \
# 1996-01-02    15.878770    15.956133    15.677626    15.793671     2.351186
# 1996-01-03    16.052837    16.783918    15.878770    15.913584     2.369037
# 1996-01-04    15.762726    15.813012    15.553845    15.766594     2.347155
# 1996-01-05    15.704703    15.704703    15.522900    15.658285     2.331031
# ...                 ...          ...          ...          ...          ...
# 2023-04-17  2424.949951  2424.949951  2349.050049  2367.449951  2367.449951
# 2023-04-18  2377.000000  2377.000000  2326.000000  2340.350098  2340.350098
# 2023-04-19  2339.050049  2357.899902  2332.199951  2352.000000  2352.000000
# 2023-04-20  2354.100098  2359.000000  2332.100098  2346.050049  2346.050049
# 2023-04-21  2350.649902  2361.000000  2336.399902  2349.000000  2349.000000
#
#                Volume
# Date
# ...

# %%
for i in range(len(top_nifty_tickers)):
    daily_data = yf.download(top_nifty_tickers[i], period="max", interval="1d")
    weekly_data = yf.download(top_nifty_tickers[i], period="max", interval="1wk")
    daily_data.to_csv("data/daily/"+top_nifty_tickers[i]+".csv")
    weekly_data.to_csv("data/weekly/"+top_nifty_tickers[i]+".csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
weekly_data
# Out:
#                   Open   High         Low       Close   Adj Close  Volume
# Date
# 2006-04-17  244.850006  247.0  215.550003  233.199997  188.289978  152610
# 2006-04-24  235.000000  240.0  213.100006  216.600006  174.886887   15597
# 2006-05-01  215.100006  225.0  215.100006  221.750000  179.045059    5425
# 2006-05-08  232.000000  260.0  231.000000  241.300003  194.830078   29560
# 2006-05-15  244.000000  249.0  220.000000  221.899994  179.166153    3967
# ...                ...    ...         ...         ...         ...     ...
# 2023-03-20    1.600000    1.6    1.600000    1.600000    1.600000       0
# 2023-03-27    1.600000    1.6    1.600000    1.600000    1.600000       0
# 2023-04-03    1.600000    1.6    1.600000    1.600000    1.600000       0
# 2023-04-10    1.600000    1.6    1.600000    1.600000    1.600000       0
# 2023-04-17    1.600000    1.6    1.600000    1.600000    1.600000       0
#
# [888 rows x 6 columns]

# %%
df=pd.read_csv("./data/daily/20MICRONS.NS.csv")

# %%
df['Date']=pd.to_datetime(df['Date'])
df=df.set_index(df.Date)

# %%
df.drop('Date',axis=1)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2008-10-06  40.000000  40.000000  15.800000  16.775000  13.774710  23501600
# 2008-10-07  16.000000  19.000000  13.925000  15.025000  12.337705   9113400
# 2008-10-08  14.000000  14.600000  12.550000  13.250000  10.880173   2464384
# 2008-10-10  12.450000  12.450000  10.825000  11.600000   9.525283   1207928
# 2008-10-13  12.150000  13.300000  11.650000  12.325000  10.120612    898692
# ...               ...        ...        ...        ...        ...       ...
# 2023-04-17  82.500000  82.599998  80.449997  82.000000  82.000000     63176
# 2023-04-18  81.500000  84.250000  81.500000  82.500000  82.500000     61918
# 2023-04-19  82.500000  83.500000  81.199997  82.250000  82.250000     43597
# 2023-04-20  82.849998  85.500000  82.099998  83.800003  83.800003     83218
# 2023-04-21  82.550003  85.300003  82.550003  83.800003  83.800003     70010
#
# [3583 rows x 6 columns]

# %%
my_range = pd.date_range(
  start="2008-10-06", end="2023-04-21", freq='B')

# %%
print(my_range.difference(df['Date']))
# Out:
# DatetimeIndex(['2008-10-09', '2008-10-28', '2008-10-30', '2008-11-13',
#                '2008-12-09', '2008-12-25', '2009-01-01', '2009-01-08',
#                '2009-01-26', '2009-02-23',
#                ...
#                '2022-08-31', '2022-10-05', '2022-10-26', '2022-11-08',
#                '2023-01-26', '2023-03-07', '2023-03-30', '2023-04-04',
#                '2023-04-07', '2023-04-14'],
#               dtype='datetime64[ns]', length=214, freq=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3583 entries, 2008-10-06 to 2023-04-21
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3583 non-null   datetime64[ns]
#  1   Open       3583 non-null   float64
#  2   High       3583 non-null   float64
#  3   Low        3583 non-null   float64
#  4   Close      3583 non-null   float64
#  5   Adj Close  3583 non-null   float64
#  6   Volume     3583 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 223.9 KB

# %%
df1
# Out:
#                  Date       Open       High        Low      Close  Adj Close
# Date
# 2008-10-06 2008-10-06  40.000000  40.000000  10.825000  11.600000   9.525283  \
# 2008-10-13 2008-10-13  12.150000  14.625000  10.025000  10.975000   9.012068
# 2008-10-20 2008-10-20  11.250000  11.625000   8.025000   8.250000   6.774446
# 2008-10-27 2008-10-27   7.625000   9.550000   6.750000   8.625000   7.082376
# 2008-11-03 2008-11-03   8.900000  10.800000   7.450000  10.350000   8.498851
# ...               ...        ...        ...        ...        ...        ...
# 2023-03-20 2023-03-20  64.000000  69.400002  64.000000  66.650002  66.650002
# 2023-03-27 2023-03-27  67.050003  79.000000  63.049999  74.300003  74.300003
# 2023-04-03 2023-04-03  75.000000  80.500000  73.150002  79.650002  79.650002
# 2023-04-10 2023-04-10  79.650002  85.699997  78.900002  82.849998  82.849998
# 2023-04-17 2023-04-17  82.500000  85.500000  80.449997  83.800003  83.800003
#
#               Volume
# Date
# ...

# %%
df1=pd.read_csv("./data/weekly/20MICRONS.NS.csv")
df1['Date']=pd.to_datetime(df1['Date'])
df1=df1.set_index(df1.Date)
df1.drop('Date',axis=1)
my_range = pd.date_range(
  start="2008-10-06", end="2023-04-17",freq='W-MON')
print(my_range.difference(df1['Date']))
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='W-MON')

# %%
names=[]
for root, dirs, files in os.walk(".\data\daily"):
    names=files

# %%
os.mkdir('./transformed_data')

# %%
df=pd.read_csv(f'./data/daily/{names[0]}')
df.Close
# Out:
# 0       16.775000
# 1       15.025000
# 2       13.250000
# 3       11.600000
# 4       12.325000
#           ...
# 3578    82.000000
# 3579    82.500000
# 3580    82.250000
# 3581    83.800003
# 3582    83.800003
# Name: Close, Length: 3583, dtype: float64

# %%
os.mkdir('./transformed_data/daily')
omitted=[]
for i in range(len(names)):
    df=pd.read_csv(f'./data/daily/{names[i]}')
    df.dropna()
    if len(df.Close)>0:
        (ca,cd)=pywt.dwt(df.Close,'haar')
        ca=np.nan_to_num(ca)
        cd=np.nan_to_num(cd)
        plt.imsave(f'./transformed_data/daily/{names[i]}.png',(ca,cd))
    else:
        omitted.append(names[i])

# %%
omitted=[]
for i in range(len(names)):
    df=pd.read_csv(f'./data/daily/{names[i]}')
    df.dropna()
    if len(df.Close)<=0:
        omitted.append(names[i])

# %%
os.mkdir('./transformed_data/weekly')
omitted_again=[]
for i in range(len(names)):
    df=pd.read_csv(f'./data/weekly/{names[i]}')
    df.dropna()
    if len(df.Close)>0 and names[i] not in omitted:
        (ca,cd)=pywt.dwt(df.Close,'haar')
        ca=np.nan_to_num(ca)
        cd=np.nan_to_num(cd)
        plt.imsave(f'./transformed_data/weekly/{names[i]}.png',(ca,cd))
    else:
        omitted_again.append(names[i])

# %%
os.mkdir('./lr')
dict={}
for i in range(len(names)):
     dict[names[i]]=i
     if names[i] not in omitted:
          im=plt.imread(f'./transformed_data/daily/{names[i]}.png')
          k=cv2.resize(im,(32,32))
          plt.imsave(f'./lr/{i}.png',k)

# %%
os.mkdir('./hr')
for i in range(len(names)):
     if names[i] not in omitted:
          im=plt.imread(f'./transformed_data/weekly/{names[i]}.png')
          k=cv2.resize(im,(128,128))
          plt.imsave(f'./hr/{i}.png',k)

# %%
import cv2
a=cv2.imread('./hr/0.png')

# %%
import os
os.listdir('./lr')
# Out:
# ['0.png',
#  '1.png',
#  '10.png',
#  '1000.png',
#  '1001.png',
#  '1002.png',
#  '1003.png',
#  '1004.png',
#  '1005.png',
#  '1006.png',
#  '1007.png',
#  '1008.png',
#  '1009.png',
#  '101.png',
#  '1010.png',
#  '1011.png',
#  '1012.png',
#  '1013.png',
#  '1014.png',
#  '1015.png',
#  '1016.png',
#  '1018.png',
#  '1019.png',
#  '102.png',
#  '1020.png',
#  '1021.png',
#  '1022.png',
#  '1023.png',
#  '1024.png',
#  '1025.png',
#  '1026.png',
#  '1027.png',
#  '1028.png',
#  '1029.png',
#  '103.png',
#  '1030.png',
#  '1032.png',
#  '1033.png',
#  '1034.png',
#  '1035.png',
#  '1036.png',
#  '1038.png',
#  '1039.png',
#  '104.png',
#  '1040.png',
#  '1041.png',
#  '1043.png',
#  '1044.png',
#  '1045.png',
#  '1046.png',
#  '1047.png',
#  '1048.png',
#  '1049.png',
#  '105.png',
#  '1052.png',
#  '1053.png',
#  '1054.png',
#  '1055.png',
#  '1056.png',
#  '1057.png',
#  '1058.png',
#  '1059.png',
#  '1060.png',
#  '1061.png',
#  '1062.png',
#  '1063.png',
#  '1064.png',
# ...
